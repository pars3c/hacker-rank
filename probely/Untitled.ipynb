# %% [markdown]
# Exercise #1
# --------------
#
# Generic risk finding score calculus:
#     1 low severity = 1
#     1 medium severity = 10
#     1 high severity = 40
#
#
# Only not fixed values count towards this score.
#
# API: https://api.probely.com/targets/ GET
#
# Scan Target: https://api.probely.com/targets/<target-id>/scan_now/ POST # Starts the scan. (<target-id> = RzXFSNHH3qUY)
#
# Scan completed with: https://api.probely.com/targets/RzXFSNHH3qUY/scans/2yvCKSRn4mZx/

# %%
import requests


def api_fetch():
    url = 'https://api.probely.com/targets/RzXFSNHH3qUY/scans/2yvCKSRn4mZx/'
    headers = (
            {
                'Content-Type': 'application/json',
                'Authorization': 'JWT eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0ZW5hbnQiOiJwcm9iZWx5IiwidXNlcm5hbWUiOiJZVWt3WjhHZFhpUmkiLCJqdGkiOiJRRDdoWUFvdjdTYnIifQ.O53R154sjyE0I5iv_ykFkboz7i5qeQwRRk-Kve9hjIs'
            })
    r = requests.get(url, headers=headers)
    return r.text

print(api_fetch())
# Out:
# {"id":"2yvCKSRn4mZx","target":{"id":"RzXFSNHH3qUY","name":"","desc":"","url":"https://test-0.ox.qa.prbly.win","stack":[{"id":"3XxEPJEIygTD","name":"PHP","desc":""},{"id":"Dzjp24cG2ZcY","name":"Nginx","desc":""}],"jira":{"connected":false,"auto_sync":false,"project_id":"","issue_type_id":"","status_mapping":null,"priority_mapping":null}},"status":"completed","started":"2019-02-17T18:46:18.583141Z","completed":"2019-02-17T19:10:22.159632Z","scan_profile":"normal","lows":24,"mediums":10,"highs":15,"created":"2019-02-17T18:46:17.376262Z","created_by":{"id":"31jGBbzvb32k","email":"","name":"exercise 1"},"changed":"2019-02-17T19:10:27.055529Z","changed_by":{"id":"fFayXxJ269nF","email":"probely@probe.ly","name":"probely"}}

# %%
def calc_risk_score(target_id):
    url = 'https://api.probely.com/targets/{}/findings/'.format(target_id)
    headers = (
            {
                'Content-Type': 'application/json',
                'Authorization': 'JWT eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0ZW5hbnQiOiJwcm9iZWx5IiwidXNlcm5hbWUiOiJZVWt3WjhHZFhpUmkiLCJqdGkiOiJRRDdoWUFvdjdTYnIifQ.O53R154sjyE0I5iv_ykFkboz7i5qeQwRRk-Kve9hjIs'
            })

    r = requests.get(url, headers=headers)
    print(r.json())
    page_total = r.json()['page_total']
    print(page_total)
    risk_sum = 0
    if page_total > 1:
        for x in range(2, page_total+1):
            url = 'https://api.probely.com/targets/RzXFSNHH3qUY/findings/?page={}'.format(str(x))
            page = requests.get(url, headers=headers)
            results = page.json()['results']
            print(url)
            for result in results:
                print(result['severity'])
                risk_sum += result['severity']
            
    else:
        page_total = r.text
        
        #print(page_total)
    print(risk_sum)

calc_risk_score('RzXFSNHH3qUY')
# Out:
# {'count': 66, 'page_total': 7, 'page': 1, 'length': 10, 'results': [{'id': 3, 'target': {'id': 'RzXFSNHH3qUY', 'name': '', 'desc': '', 'url': 'https://test-0.ox.qa.prbly.win', 'stack': [{'id': '3XxEPJEIygTD', 'name': 'PHP', 'desc': ''}, {'id': 'Dzjp24cG2ZcY', 'name': 'Nginx', 'desc': ''}], 'jira': {'connected': False, 'auto_sync': False, 'project_id': '', 'issue_type_id': '', 'status_mapping': None, 'priority_mapping': None}}, 'scans': ['2iwUBYsXDPxV', '2JRUeZFMMAUu', '2mA78rVw3M6Z', '2RnxpEEm2qd5', '2sWWJuuy8MDu', '2t1hQBW4rki3', '2vRtvAKt16Fh', '2wotrA3oK8nu', '2xJQbLKg2YF9', '2yvCKSRn4mZx', '2ZBpZG2uN5ag', '3CNwZsdWtQJS', '3d9qjChYgLVm', '3hbQvcGEmLbW', '3KFJ41NT2HKB', '3n7djMJH5mYk', '3SstkgDX8Y6j', '3swsdptr95wh', '3UfpSCPLPkqT', '3VHfH2m9dbq4', '3wPDep7GiCSc', '48Jjq5D1kXBc', '4DAmEKNr5fHH', '4DbEACC6f83r', '7AjPs8PSdvne', 'APuBqYUdW3Sz', 'ckefz4A3GjyR', 'ej8KbqvkbjKH', 'm9AtAz9corER', 'ohxpSnKyQEHi', 'UUG8b7c1b2vV', 'xYofwr9vTejo', 'Y6Dm69FBPncC', 'zY45f5XCfT69'], 'labels': [], 'fix': "The correct solution is to update WordPress to its latest stable version, which will fix any known vulnerability, improving the security of the web application.\r\n\r\nThe easiest method to install the latest version is through the WordPress update feature:\r\n1. go to the `/wp-admin/update-core.php` page on your application. \r\n1. an indication of an update should appear: `An updated version of WordPress is available.` If it doesn't appear, press `Check Again`.\r\n1. press `Update Now` and follow the instructions. This should only take a few minutes.\r\n1. you should also update any plugin or theme you have installed, since these are often a source of vulnerabilities. To this press `Update Plugins` and afterwards `Update Themes`.\r\n\r\n\r\nIf you cannot update through the site (for instance, if the update process fails), you will have to do it manually. The manual update process is described at the WordPress site, at `https://codex.wordpress.org/Updating_WordPress#Manual_Update`.", 'requests': [], 'evidence': '\n\nYou have Wordpress version 4.2, first published at 2015-04-23. This version is outdated and has known vulnerabilities.\n\n\n\n', 'extra': 'The current version has the following list of known vulnerabilities:\n\n* WordPress &lt;= 4.2 - Unauthenticated Stored Cross-Site Scripting (XSS)\n\n* WordPress 4.1-4.2.1 - Unauthenticated Genericons Cross-Site Scripting (XSS)\n\n* WordPress &lt;= 4.2.2 - Authenticated Stored Cross-Site Scripting (XSS) [CVE-2015-5622, CVE-2015-5623]\n\n* WordPress &lt;= 4.2.3 - wp_untrash_post_comments SQL Injection  [CVE-2015-2213]\n\n* WordPress &lt;= 4.2.3 - Timing Side Channel Attack [CVE-2015-5730]\n\n* WordPress &lt;= 4.2.3 - Widgets Title Cross-Site Scripting (XSS) [CVE-2015-5732]\n\n* WordPress &lt;= 4.2.3 - Nav Menu Title Cross-Site Scripting (XSS) [CVE-2015-5733]\n\n* WordPress &lt;= 4.2.3 - Legacy Theme Preview Cross-Site Scripting (XSS) [CVE-2015-5734]\n\n* WordPress &lt;= 4.3 - Authenticated Shortcode Tags Cross-Site Scripting (XSS) [CVE-2015-5714]\n\n* WordPress &lt;= 4.3 - User List Table Cross-Site Scripting (XSS) [CVE-2015-7989]\n\n* WordPress &lt;= 4.3 - Publish Post &amp; Mark as Sticky Permission Issue [CVE-2015-5715]\n\n* WordPress  3.7-4.4 - Authenticated Cross-Site Scripting (XSS) [CVE-2016-1564]\n\n* WordPress 3.7-4.4.1 - Local URIs Server Side Request Forgery (SSRF) [CVE-2016-2222]\n\n* WordPress 3.7-4.4.1 - Open Redirect [CVE-2016-2221]\n\n* WordPress &lt;= 4.4.2 - SSRF Bypass using Octal &amp; Hexedecimal IP addresses [CVE-2016-4029]\n\n* WordPress &lt;= 4.4.2 - Reflected XSS in Network Settings [CVE-2016-6634]\n\n* WordPress &lt;= 4.4.2 - Script Compression Option CSRF [CVE-2016-6635]\n\n* WordPress 4.2-4.5.1 - MediaElement.js Reflected Cross-Site Scripting (XSS) [CVE-2016-4567]\n\n* WordPress &lt;= 4.5.1 - Pupload Same Origin Method Execution (SOME) [CVE-2016-4566]\n\n* WordPress 4.2-4.5.2 - Authenticated Attachment Name Stored XSS [CVE-2016-5833, CVE-2016-5834]\n\n* WordPress  ...
# 7
# https://api.probely.com/targets/RzXFSNHH3qUY/findings/?page=2
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 20
# 20
# 20
# https://api.probely.com/targets/RzXFSNHH3qUY/findings/?page=3
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# https://api.probely.com/targets/RzXFSNHH3qUY/findings/?page=4
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 10
# https://api.probely.com/targets/RzXFSNHH3qUY/findings/?page=5
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# https://api.probely.com/targets/RzXFSNHH3qUY/findings/?page=6
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# https://api.probely.com/targets/RzXFSNHH3qUY/findings/?page=7
# 10
# 10
# 10
# 10
# 10
# 10
# 920
